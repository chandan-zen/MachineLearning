# %% [markdown]
# # Telco Churn Analysis
#
# #### Data Set Info: *Sample Data Set containing Telco customer data and showing customers left last month*

# %%
#Imports

import numpy as np
import pandas as pd
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# *Load the Data File*

# %%
telco_base_data = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %% [markdown]
# *Look at the top 5 Records*

# %%
telco_base_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# *Check various attributes of the data like shape(rows and cols), Columns, datatypes*

# %%
telco_base_data.shape
# Out:
# (7043, 21)

# %%
telco_base_data.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
#Checking the data types of all the columns
telco_base_data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#Check the decriptive statistics of numeric variables (Only for Numeric)
telco_base_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# * SeniorCitizen is actually a categorical hence the 25%-50%-75% distribution isn't proper
# * 75% customers have tenure less than 55 months
# * Average monthly charges are USD 64.76 whereas 25% customers pay more than USD 89.85 per month

# %%
#plot Churn - > To identify Churners' ratio
telco_base_data['Churn'].value_counts().plot(kind='barh',figsize=(8,6))
plt.xlabel("Count",labelpad=14)
plt.ylabel("Target Variable",labelpad=14)
plt.title("Count the Target Variable per category",y=1.02);

# %%
# (%) Churn values
100*telco_base_data['Churn'].value_counts()/len(telco_base_data['Churn'])
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %%
# Actual Churn Values
telco_base_data['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# * Data is highly imbalanced, ratio =  73:27
# * So we analyse the data with other features while taking the target values seperately to get some insights

# %%
# Concise summary of the dataframe, as we have too many cols., we are using verbose = True mode
telco_base_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Code to plot missing data
# reset_index | will give indexed values for the null records | if avlb.
missing = pd.DataFrame((telco_base_data.isnull().sum())*100/telco_base_data.shape[0]).reset_index()
plt.figure(figsize = (16,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation=90,fontsize=7) #To write labels at certain angle
plt.title("Percentage of Missing Values")
plt.ylabel("PERCENTAGE")
plt.show()
# Out:
# D:\Softwares\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Missing Data - Initial Intuition
# * Here, we don't have any missing data.
#
# -- General Thumb Rules:
#
# * For features with less missing values- can use regression to predict the missing values or fill with the mean of the values present, depending on the feature.
# * For features with very high number of missing values- it is better to drop those columns as they give very less insight on analysis.
# * As there's no thumb rule on what criteria do we delete the columns with high number of missing values, but generally you can delete the columns, if you have more than 30-40% of missing values. But again there's a catch here, for example, Is_Car & Car_Type, People having no cars, will obviously have Car_Type as NaN (null), but that doesn't make this column useless, so decisions has to be taken wisely.

# %% [markdown]
# ### Data Cleaning
# #### 1.) Create a copy base data for manipulation & processing

# %%
telco_data = telco_base_data.copy() #To manipulate the data, while keeping the original data set intact

# %% [markdown]
# #### 2.) Total Charges should be numeric amount. Let's Convert it to numerical data type using (pd.to_numeric)

# %%
telco_data.TotalCharges = pd.to_numeric(telco_data.TotalCharges, errors='coerce')
telco_data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# ##### NOTE: Always convert object data - > Numeric Data || To find the real null values count
# #### 3.) As we can see there are 11 missing values in TotalCharges column. Let's Check these records

# %%
telco_data.loc[telco_data['TotalCharges'].isnull() == True] #To locate the null values #isnull() gives a boolean
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# #### 4.) Missing Value Treatment
#     *  Since the % of these records compared to the total data set is very low i.e. 0.15%. It is safe to ignore them for further processing

# %%
#Removing missing values
telco_data.dropna(how = 'any', inplace=True)

# %% [markdown]
# #### 5.) Divide the customers into bins based on tenure ( using pd.cut)
# * e.g. for tenure < 12 months: assign a tenure group of 1-12, for the tenure between 1-2 years, tenure group of 13-24:, so on..

# %%
#Get the max tenure
print(telco_data['tenure'].max()) #72
# Out:
# 72

# %%
# Group the tenure in bins of 12 months
labels = ["{0} - {1}".format(i, i+11) for i in range(1,72,12)]

# Use "pd.cut" when you need to sort the values in bins equally
# Bin labels must be 1 fewer than the Edge of bins || so range = 1, 72 , bins = 6 , 1 fewer needed => range(1,80,12)
telco_data['tenure_group'] = pd.cut(telco_data.tenure, range(1,80,12), right=False, labels=labels)

# %%
telco_data['tenure_group'].value_counts()
# Out:
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: tenure_group, dtype: int64

# %% [markdown]
# #### 6. Remove columns not required for processing

# %%
#drop column CustomerID and tenure(as we already have bins)
telco_data.drop(columns=['customerID','tenure'], axis=1, inplace=True)
telco_data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# ### Data Exploration
# *1.* Plot distribution of individual predictors by churn

# %% [markdown]
# #### Univariate Analysis

# %%
# Create a predictor using FOR loop and ENUMERATE( gives index value & value) for each categorical column w.r.t. 'Target' column
for i, predictor in enumerate(telco_data.drop(columns=['Churn','TotalCharges','MonthlyCharges'])):
    plt.figure(i)
    sns.countplot(data=telco_data, x=predictor, hue='Churn')

# %% [markdown]
# *2.* Convert the target variable 'Churn' in a binary numeric variable i.e. Yes=1; No=0
# #### Using (np.where)

# %%
telco_data['Churn'] = np.where(telco_data.Churn == 'Yes',1,0)
telco_data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# *3.* Convert all the categorical variables into DUMMY variables

# %%
telco_data_dummies = pd.get_dummies(telco_data) #Converts all the categorical data columns into Dummy Variables
telco_data_dummies.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0              1
# 1              0           56.95       1889.50      0              0
# 2              0           53.85        108.15      1              0
# 3              0           42.30       1840.75      0              0
# 4              0           70.70        151.65      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# ...

# %% [markdown]
# *4.* Relationship between Monthly Charges and Total Charges

# %%
sns.lmplot(data=telco_data_dummies, x='MonthlyCharges', y='TotalCharges', fit_reg=False)

# %% [markdown]
# Total Charges increases as Monthly Charges increases-As expected

# %% [markdown]
# *5.* Churn by Monthly Charges and Total Charges | Using KDE plot | Measuring Density

# %%
#Prepares KDE plot for Monthly Charges with Churn == 0 condition
Mth = sns.kdeplot(telco_data_dummies.MonthlyCharges[(telco_data_dummies['Churn'] == 0)], color="Red", shade=True)
#Prepares KDE plot for Monthly Charges with Churn == 1 condition
Mth = sns.kdeplot(telco_data_dummies.MonthlyCharges[telco_data_dummies['Churn'] == 1], color="Blue", shade=True)
Mth.legend(["NotChurn","Churn"], loc='upper right')
Mth.set_xlabel('Monthly Charges')
Mth.set_ylabel('Density')
Mth.set_title('Monthly Charges by Churn')
# Out:
# Text(0.5, 1.0, 'Monthly Charges by Churn')

# %% [markdown]
# ##### Insight: Churn is high when Monthly Charges are high

# %%
#Prepares KDE plot for Total Charges with Churn == 0 condition
Tot = sns.kdeplot(telco_data_dummies.TotalCharges[telco_data_dummies['Churn']==0], color="Red", shade = True)
#Prepares KDE plot for Total Charges with Churn == 1 condition
Tot = sns.kdeplot(telco_data_dummies.TotalCharges[telco_data_dummies['Churn']==1], color="Blue", shade=True)
Tot.legend(["NotChurn","Churn"], loc="upper right")
Tot.set_xlabel("Total Charges")
Tot.set_ylabel("Density")
Tot.set_title("Total Charges by Churn")
# Out:
# Text(0.5, 1.0, 'Total Charges by Churn')

# %% [markdown]
# ##### Suprising Insights, as Higher Churn at lower Total Charges
#
# However if we combine the insights of 3 parameters i.e. Tenure, Monthly Charges & Total Charges then the picture is bit clear :- Higher Monthly Charge at lower tenure results into lower Total Charge. Hence, all these 3 factors viz Higher **Monthly Charge, Lower tenure** and **Lower Total Charge** are linked to **High Churn.**

# %% [markdown]
# *6.* Build a Correlation of all predictors with Churn

# %%
plt.figure(figsize = (20,8))
telco_data_dummies.corr()['Churn'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# *Derived Insights*
# * **High Churn** seen in case of **Month to Month contracts, No Online Security, No Tech Support, First Year of Subscription** and **Fibre optics Internet**
# * **LOW Churn** is seen in case of **Long term contracts, Subscriptions w/o internet services**, and **Customers engaged for 5+ years**
# * Factors like **Gender, Availability of Phone Service** and **hashtag of multiple lines** have almost **NO** impact on Churn.
# * This is also evident from the **HeatMap** below

# %%
plt.figure(figsize=(12,12))
sns.heatmap(telco_data_dummies.corr(), cmap="Paired")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bivariate Analysis

# %%
# Analyse 2 variables || Create 2 dataframes || One for Churners, One for Non-Churners
new_df1_target0 = telco_data.loc[telco_data["Churn"]==0]
new_df1_target1 = telco_data.loc[telco_data["Churn"]==1]

# %% [markdown]
# ###### In Bivariate Analysis, we don't use FOR, ENUMERATE || We have to create a User-Defined PLOT
# * In Bivariate Analysis,
#     * Step-1: Create a Uniplot fun.
#     * Step-2: Set Style, Context, Parameters(rcparams)
#     * Step-3: Use Pandas, & Matplolib to set Series, Width, size_inches, and scale of the plot
#     * Step-4: Create a Uniplot & plot it

# %%
def uniplot(df,col,title,hue=None): #Initiated the functions , that can be called out in plotting final graph
    
    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"]=20
    plt.rcParams["axes.titlesize"]=22
    plt.rcParams["axes.titlepad"]=30
    
    temp = pd.Series(data=hue)
    fig, ax = plt.subplots()
    width = len(df[col].unique())+7+4*len(temp.unique())
    fig.set_size_inches(width, 8)
    plt.xticks(rotation=45)
    plt.yscale('log')
    plt.title(title)
    # Will set how the input will act in the graph and how the order of calculation will be
    ax = sns.countplot(data = df, x=col, order=df[col].value_counts().index, hue=hue, palette='bright') 
    
    plt.show()

# %%
#Plotting the Uniplot for "Partner" based on "Gender"
uniplot(new_df1_target1, col='Partner', title='Distribution of Gender for Churned Customers', hue='gender')

# %%
#Plotting the Uniplot for "Partner" based on "Gender"
uniplot(new_df1_target0, col='Partner', title='Distribution of Gender for Non-Churned Customers', hue='gender')

# %%
uniplot(new_df1_target0, col='PaymentMethod', title='Distribution of PaymentMethod for Non-Churned customers', hue='gender')

# %%
uniplot(new_df1_target1, col='PaymentMethod', title = 'Distribution of Payment Method for Churned Customers', hue='gender')

# %%
uniplot(new_df1_target0, col='Contract', title='Distribution of Contract for Non-Churned', hue='gender')

# %%
uniplot(new_df1_target1, col='Contract', title='Distribution of Contract for Churned Customers', hue='gender')

# %%
uniplot(new_df1_target1,col='TechSupport',title='Distribution of TechSupport for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='SeniorCitizen',title='Distribution of TechSupport for Churned Customers',hue='gender')

# %% [markdown]
# ### CONCLUSION
# These are some of the quick insights from this exercise:
#
# * 1.) Electronic check medium are the highest churners
# * 2.) Contract Type - Monthly customers are more likely to churn because of no contract terms, as they are free to go customers.
# * 3.) No Online security, No Tech Support category are high churners
# * 4.) Non senior Citizens are high churners
